# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from matplotlib.offsetbox import AnchoredText
import matplotlib.font_manager as font_manager

# %%
data = np.genfromtxt('VIS_timeline.csv', delimiter=",", skip_header=1, dtype=float)
datb = pd.read_csv('VIS_timeline.csv', sep=',', dtype=float)

date = data[:,0]
NDVI = data[:,10]
NDRE = data[:,9]

CIGR = data[:,6]
CIGR = CIGR.reshape(-1, 1)
scaler = MinMaxScaler()
scaler.fit(CIGR)
CIGR = scaler.transform(CIGR)

CIRE = data[:,7]
CIRE = CIRE.reshape(-1, 1)
scaler = MinMaxScaler()
scaler.fit(CIRE)
CIRE = scaler.transform(CIRE)

MTCI = data[:,8]
MTCI = MTCI.reshape(-1, 1)
scaler = MinMaxScaler()
scaler.fit(MTCI)
MTCI = scaler.transform(MTCI)

RDVI = data[:,11]
RDVI = RDVI.reshape(-1, 1)
scaler = MinMaxScaler()
scaler.fit(RDVI)
RDVI = scaler.transform(RDVI)

datb
# Out:
#            Date           B1           B2           B3           B4  \
# 0    11052020.0  1297.176148  3104.644614  1220.159543  6454.435510
# 1    11052020.0  1328.586805  3293.080684  1253.720016  6856.567878
# 2    11052020.0  1745.282920  3682.542403  1919.136876  7253.285608
# 3    11052020.0  1579.011614  3490.827152  1595.495093  7058.464010
# 4    11052020.0  1775.804986  3829.994191  1923.149621  7866.406462
# ..          ...          ...          ...          ...          ...
# 265  12082020.0  1365.126399  2301.312862  3069.771033  4505.936635
# 266  12082020.0  1571.174497  2834.729457  3467.678106  5459.939555
# 267  12082020.0  1810.474952  3445.760433  4297.828572  6790.979482
# 268  12082020.0  1759.929299  3155.810255  4128.831451  6111.983913
# 269  12082020.0  1890.017348  3267.933584  4146.720171  6081.523293
#
#                B5      CIGR      CIRE      MTCI      NDRE      NDVI  \
# 0    14405.241290  3.662852  1.235717  1.523455  0.380695  0.842501
# ...

# %%
datc = np.genfromtxt('AGB_VIS_Timeline2.csv', delimiter=",", skip_header=1, dtype=float)
datd = pd.read_csv('AGB_VIS_Timeline2.csv', sep=',', dtype=float)
y_AGB = datc[:,3]
Y = y_AGB #or y_n
datd
# Out:
#      Sample group  AGB  (gDM m-2)  Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0      20072020.0     1323.794060         NaN   113.101979  13052020.0
# 1      20072020.0     1181.513078         NaN   333.959032  29052020.0
# 2      20072020.0     1396.620480         NaN   673.738016         NaN
# 3      20072020.0     1070.987250         NaN  1013.516999  19062020.0
# 4      20072020.0     1705.515871         NaN  1119.604333         NaN
# ..            ...             ...         ...          ...         ...
# 112    13052020.0      135.885714         NaN          NaN         NaN
# 113    13052020.0       72.736842         NaN          NaN         NaN
# 114    13052020.0      105.764706         NaN          NaN         NaN
# 115    13052020.0      130.000000         NaN          NaN         NaN
# 116    13052020.0       91.095238         NaN          NaN         NaN
#
#      Unnamed: 5
# 0    679.557967
# 1    339.778984
# 2           NaN
# 3    212.174667
# 4    106.087334
# ...

# %%
date = np.genfromtxt('LAI_MasterTimeline.csv', delimiter=",", skip_header=1, dtype=float)
datf = pd.read_csv('LAI_MasterTimeline.csv', sep=',', dtype=float)
y_LAI = date[:,3]
Y2 = y_LAI #or y_n
datf
# Out:
#           Date        LAI    datePlot   meanLAI  Unnamed: 4  Unnamed: 5
# 0   20200513.0   0.714637  20200513.0  0.598744         NaN         NaN
# 1   20200513.0   0.442543  20200527.0  6.494027         NaN         NaN
# 2   20200513.0   0.629567  20200610.0  7.733767         NaN         NaN
# 3   20200513.0   0.858885  20200618.0  8.348779    1.412866    0.706433
# 4   20200513.0   0.725400  20200619.0  7.642346         NaN         NaN
# 5   20200513.0   0.675385  20200621.0  6.935913         NaN         NaN
# 6   20200513.0   0.581071  20200712.0       NaN         NaN         NaN
# 7   20200513.0   0.558625  20200718.0       NaN         NaN         NaN
# 8   20200513.0   0.457919  20200801.0       NaN         NaN         NaN
# 9   20200513.0   0.418512  20200812.0       NaN         NaN         NaN
# 10  20200513.0   0.437803         NaN       NaN         NaN         NaN
# 11  20200513.0   0.684576         NaN       NaN         NaN         NaN
# ...

# %%
a = Y[0]
b = Y[1]
c = Y[2]
d = Y[3]
e = Y[4]
f = Y[5]
g = Y[6]
h = Y[7]
i = Y[8]
AGB = [a, b, c, d, e, f, g, h, i]

# %%
j = Y2[0]
k = Y2[1]
l = Y2[2]
m = Y2[3]
n = Y2[4]
o = Y2[5]
p = Y2[6]
q = Y2[7]
r = Y2[8]
LAI = [j, k, l, m, n, o, p, q, r]

# %%
NDVIa = NDVI[0:30]
NDVIb = NDVI[30:60]
NDVIc = NDVI[60:90]
NDVId = NDVI[90:120]
NDVIe = NDVI[120:150]
NDVIf = NDVI[150:180]
NDVIg = NDVI[180:210]
NDVIh = NDVI[210:240]
NDVIi = NDVI[240:270]

NDREa = NDRE[0:30]
NDREb = NDRE[30:60]
NDREc = NDRE[60:90]
NDREd = NDRE[90:120]
NDREe = NDRE[120:150]
NDREf = NDRE[150:180]
NDREg = NDRE[180:210]
NDREh = NDRE[210:240]
NDREi = NDRE[240:270]

CIGRa = CIGR[0:30]
CIGRb = CIGR[30:60]
CIGRc = CIGR[60:90]
CIGRd = CIGR[90:120]
CIGRe = CIGR[120:150]
CIGRf = CIGR[150:180]
CIGRg = CIGR[180:210]
CIGRh = CIGR[210:240]
CIGRi = CIGR[240:270]

CIREa = CIRE[0:30]
CIREb = CIRE[30:60]
CIREc = CIRE[60:90]
CIREd = CIRE[90:120]
CIREe = CIRE[120:150]
CIREf = CIRE[150:180]
CIREg = CIRE[180:210]
CIREh = CIRE[210:240]
CIREi = CIRE[240:270]

MTCIa = MTCI[0:30]
MTCIb = MTCI[30:60]
MTCIc = MTCI[60:90]
MTCId = MTCI[90:120]
MTCIe = MTCI[120:150]
MTCIf = MTCI[150:180]
MTCIg = MTCI[180:210]
MTCIh = MTCI[210:240]
MTCIi = MTCI[240:270]

RDVIa = RDVI[0:30]
RDVIb = RDVI[30:60]
RDVIc = RDVI[60:90]
RDVId = RDVI[90:120]
RDVIe = RDVI[120:150]
RDVIf = RDVI[150:180]
RDVIg = RDVI[180:210]
RDVIh = RDVI[210:240]
RDVIi = RDVI[240:270]

# %%
NDVIa = np.mean(NDVIa)
NDVIb = np.mean(NDVIb)
NDVIc = np.mean(NDVIc)
NDVId = np.mean(NDVId)
NDVIe = np.mean(NDVIe)
NDVIf = np.mean(NDVIf)
NDVIg = np.mean(NDVIg)
NDVIh = np.mean(NDVIh)
NDVIi = np.mean(NDVIi)
ndviList = [NDVIa, NDVIb, NDVIc, NDVId, NDVIe, NDVIf, NDVIg, NDVIh, NDVIi]

NDREa = np.mean(NDREa)
NDREb = np.mean(NDREb)
NDREc = np.mean(NDREc)
NDREd = np.mean(NDREd)
NDREe = np.mean(NDREe)
NDREf = np.mean(NDREf)
NDREg = np.mean(NDREg)
NDREh = np.mean(NDREh)
NDREi = np.mean(NDREi)
ndreList = [NDREa, NDREb, NDREc, NDREd, NDREe, NDREf, NDREg, NDREh, NDREi]

CIGRa = np.mean(CIGRa)
CIGRb = np.mean(CIGRb)
CIGRc = np.mean(CIGRc)
CIGRd = np.mean(CIGRd)
CIGRe = np.mean(CIGRe)
CIGRf = np.mean(CIGRf)
CIGRg = np.mean(CIGRg)
CIGRh = np.mean(CIGRh)
CIGRi = np.mean(CIGRi)
cigrList = [CIGRa, CIGRb, CIGRc, CIGRd, CIGRe, CIGRf, CIGRg, CIGRh, CIGRi]

CIREa = np.mean(CIREa)
CIREb = np.mean(CIREb)
CIREc = np.mean(CIREc)
CIREd = np.mean(CIREd)
CIREe = np.mean(CIREe)
CIREf = np.mean(CIREf)
CIREg = np.mean(CIREg)
CIREh = np.mean(CIREh)
CIREi = np.mean(CIREi)
cireList = [CIREa, CIREb, CIREc, CIREd, CIREe, CIREf, CIREg, CIREh, CIREi]

MTCIa = np.mean(MTCIa)
MTCIb = np.mean(MTCIb)
MTCIc = np.mean(MTCIc)
MTCId = np.mean(MTCId)
MTCIe = np.mean(MTCIe)
MTCIf = np.mean(MTCIf)
MTCIg = np.mean(MTCIg)
MTCIh = np.mean(MTCIh)
MTCIi = np.mean(MTCIi)
mtciList = [MTCIa, MTCIb, MTCIc, MTCId, MTCIe, MTCIf, MTCIg, MTCIh, MTCIi]

RDVIa = np.mean(RDVIa)
RDVIb = np.mean(RDVIb)
RDVIc = np.mean(RDVIc)
RDVId = np.mean(RDVId)
RDVIe = np.mean(RDVIe)
RDVIf = np.mean(RDVIf)
RDVIg = np.mean(RDVIg)
RDVIh = np.mean(RDVIh)
RDVIi = np.mean(RDVIi)
rdviList = [RDVIa, RDVIb, RDVIc, RDVId, RDVIe, RDVIf, RDVIg, RDVIh, RDVIi]

# %%
dates = ['11-05', '31-05', '18-06', '19-06', '21-06', '12-07', '18-07', '01-08', '12-08']
fig, ax = plt.subplots()
#plt.figure(figsize=(20,10))
axisFont = font_manager.FontProperties(family='Times New Roman',
                                   style='normal', size=15)

legendFont = font_manager.FontProperties(family='Times New Roman',
                                   style='normal', size=13)

ax.plot(dates, ndviList, alpha=0.5, color='blue', linewidth=2)
ax.plot(dates, ndreList, alpha=0.5, color='orange', linewidth=2)
ax.plot(dates, cigrList, alpha=0.5, color='green', linewidth=2)
ax.plot(dates, cireList, alpha=0.5, color='red', linewidth=2)
ax.plot(dates, mtciList, alpha=0.5, color='purple', linewidth=2)
ax.plot(dates, rdviList, alpha=0.5, color='yellow', linewidth=2)
ax.grid(True)
ax.set_xlabel('Date of Flight', fontproperties=axisFont)
ax.set_ylabel('VIS', fontproperties=axisFont)
#ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
#ax2.set_ylabel('LAI', fontproperties=axisFont)  # we already handled the x-label with ax1
#ax2.plot(dates, LAI, 'r--', alpha=0.7)
fig.legend(('NDVI', 'NDRE', 'CIGR', 'CIRE', 'MTCI', 'RDVI'),
           bbox_to_anchor=(0.785, 0.76, 0.1, 0.1), borderaxespad=0., prop=legendFont)
#fig.legend(('NDVI', 'NDRE', 'CIGR', 'CIRE', 'MTCI', 'RDVI', 'LAI' ), loc='lower center')
#ax2.legend(('LAI'), loc='upper right')
plt.savefig('VISLAItimelineComp.png', dpi=350, bbox_inches='tight')

# %%
dates = ['11-05', '31-05', '18-06', '19-06', '21-06', '12-07', '18-07', '01-08', '12-08']
fig, ax = plt.subplots()
#plt.figure(figsize=(20,10))
axisFont = font_manager.FontProperties(family='Times New Roman',
                                   style='normal', size=15)

titleFont = font_manager.FontProperties(family='Times New Roman',
                                   style='normal', size=18)

legendFont = font_manager.FontProperties(family='Times New Roman',
                                   style='normal', size=13)

ax.plot(dates, LAI, alpha=0.5, color='blue', linewidth=2)
ax.grid(True)
ax.set_title('Comparison of Average AGB and LAI\nOver the Growing Season', fontproperties=titleFont)
ax.set_xlabel('Date of Flight', fontproperties=axisFont)
ax.set_ylabel('LAI', fontproperties=axisFont)
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('AGB', fontproperties=axisFont)  # we already handled the x-label with ax1
ax2.plot(dates, AGB, color='orange', alpha=0.5, linewidth=2)
fig.legend(('LAI', 'AGB'),
           bbox_to_anchor=(0.78, 0.2, 0.1, 0.1), borderaxespad=0., prop=legendFont)
#fig.legend(('NDVI', 'NDRE', 'CIGR', 'CIRE', 'MTCI', 'RDVI', 'LAI' ), loc='lower center')
#ax2.legend(('LAI'), loc='upper right')
plt.savefig('LAIAGBtimelineComp.png', dpi=350, bbox_inches='tight')
